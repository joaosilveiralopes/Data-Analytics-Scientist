# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder 
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
credito = pd.read_csv('Credit.csv')
credito.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
# 4                       3         'male single'          none  ...
#
#     property_magnitude age  other_payment_plans     housing existing_credits  \
# 0        'real estate'  67                 none         own                2
# 1        'real estate'  22                 none         own                1
# 2        'real estate'  49                 none         own                1
# 3     'life insurance'  45                 none  'for free'                1
# 4  'no known property'  53                 none  'for free'                2
#
#                     job num_dependents  own_telephone foreign_worker class
# 0               skilled              1            yes            yes  good
# 1               skilled              1           none            yes   bad
# 2  'unskilled resident'              2           none            yes  good
# 3               skilled              2           none            yes  good
# 4               skilled              2           none            yes   bad
#
# [5 rows x 21 columns]

# %%
previsores = credito.iloc[:,0:20].values
classe = credito.iloc[:,20].values

# %%
labelencoder = LabelEncoder()
previsores[:,0] = labelencoder.fit_transform(previsores[:,0])
previsores[:,2] = labelencoder.fit_transform(previsores[:,2])
previsores[:,3] = labelencoder.fit_transform(previsores[:,3])
previsores[:,5] = labelencoder.fit_transform(previsores[:,5])
previsores[:,6] = labelencoder.fit_transform(previsores[:,6])
previsores[:,8] = labelencoder.fit_transform(previsores[:,8])
previsores[:,9] = labelencoder.fit_transform(previsores[:,9])
previsores[:,11] = labelencoder.fit_transform(previsores[:,11])
previsores[:,13] = labelencoder.fit_transform(previsores[:,13])
previsores[:,14] = labelencoder.fit_transform(previsores[:,14])
previsores[:,16] = labelencoder.fit_transform(previsores[:,16])
previsores[:,18] = labelencoder.fit_transform(previsores[:,18])
previsores[:,19] = labelencoder.fit_transform(previsores[:,19])

# %%
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(previsores,
                                                                 classe, 
                                                                 test_size = 0.3,
                                                                 random_state = 0)

# %%
floresta = RandomForestClassifier(n_estimators=100)
floresta.fit(X_treinamento, y_treinamento)
# Out:
# RandomForestClassifier()

# %% [markdown]
# Visualização dos atributos principais

# %%
floresta.estimators_ # ele vai trazer os parâmetros de todos as arvores que foram induzidas 

#floresta.estimator_[1]
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=1184421428),
#  DecisionTreeClassifier(max_features='sqrt', random_state=505975727),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1112328475),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2063609984),
#  DecisionTreeClassifier(max_features='sqrt', random_state=322150381),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1728000124),
#  DecisionTreeClassifier(max_features='sqrt', random_state=152304565),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1320753363),
#  DecisionTreeClassifier(max_features='sqrt', random_state=292802159),
#  DecisionTreeClassifier(max_features='sqrt', random_state=923276291),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1531358115),
#  DecisionTreeClassifier(max_features='sqrt', random_state=884033397),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1347982429),
#  DecisionTreeClassifier(max_features='sqrt', random_state=298626807),
#  DecisionTreeClassifier(max_features='sqrt', random_state=549141511),
#  DecisionTreeClassifier(max_features='sqrt', random_state=542248983),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1960357879),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1494026429),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1436993004),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1411515847),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1271817532),
#  DecisionTreeClassifier(max_features='sqrt', random_state=33456927),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1429362423),
#  DecisionTreeClassifier(max_features='sqrt', random_state=893632691),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1087244923),
#  DecisionTreeClassifier(max_features='sqrt', random_state=300053208),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1488170434),
#  DecisionTreeClassifier(max_features='sqrt', random_state=794262738),
#  DecisionTreeClassifier(max_features='sqrt', random_state=578928420),
#  DecisionTreeClassifier(max_features='sqrt', random_state=787536658),
#  DecisionTreeClassifier(max_features='sqrt', random_state=475835051),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1982195684),
#  DecisionTreeClassifier(max_features='sqrt', random_state=879506770),
#  DecisionTreeClassifier(max_features='sqrt', random_state=257052779),
#  DecisionTreeClassifier(max_features='sqrt', random_state=687229146),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1482375367),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1345323015),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1814427146),
#  DecisionTreeClassifier(max_features='sqrt', random_state=687040520),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1055578698),
#  DecisionTreeClassifier(max_features='sqrt', random_state=346223800),
#  DecisionTreeClassifier(max_features='sqrt', random_state=262405710),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2028830537),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1569563335),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1050580406),
#  DecisionTreeClassifier(max_features='sqrt', random_state=786427017),
#  DecisionTreeClassifier(max_features='sqrt', random_state=170303463),
#  DecisionTreeClassifier(max_features='sqrt', random_state=294390297),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1340845099),
#  DecisionTreeClassifier(max_features='sqrt', random_state=319067683),
#  DecisionTreeClassifier(max_features='sqrt', random_state=208442990),
#  DecisionTreeClassifier(max_features='sqrt', random_state=545361172),
#  DecisionTreeClassifier(max_features='sqrt', random_state=813713217),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1531381664),
#  DecisionTreeClassifier(max_features='sqrt', random_state=271911162),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1683739091),
#  DecisionTreeClassifier(max_features='sqrt', random_state=721034407),
#  DecisionTreeClassifier(max_features='sqrt', random_state=643327603),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1703512054),
#  DecisionTreeClassifier(max_features='sqrt', random_state=860352359),
#  DecisionTreeClassifier(max_features='sqrt', random_state=517771262),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1303673693),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1163504492),
#  DecisionTreeClassifier(max_features='sqrt', random_state=238641502),
#  DecisionTreeClassifier(max_features='sqrt', random_state=482029064),
#  DecisionTreeClassifier(max_features='sqrt', random_state=381894629),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1025128311),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1316444328),
#  DecisionTreeClassifier(max_features='sqrt', random_state=253074684),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1317571954),
#  DecisionTreeClassifier(max_features='sqrt', random_state=896820795),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1098291455),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1431205808),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1092650554),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1678240241),
#  DecisionTreeClassifier(max_features='sqrt', random_state=734223115),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1931459223),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1107379302),
#  DecisionTreeClassifier(max_features='sqrt', random_state=819662347),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1311218342),
#  DecisionTreeClassifier(max_features='sqrt', random_state=50375300),
#  DecisionTreeClassifier(max_features='sqrt', random_state=770967257),
#  DecisionTreeClassifier(max_features='sqrt', random_state=646987664),
#  DecisionTreeClassifier(max_features='sqrt', random_state=411561493),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1129842508),
#  DecisionTreeClassifier(max_features='sqrt', random_state=669212771),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1484935210),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1373899513),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2014229660),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1123400699),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1445231791),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1237095171),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1740089692),
#  DecisionTreeClassifier(max_features='sqrt', random_state=26198316),
#  DecisionTreeClassifier(max_features='sqrt', random_state=496568334),
#  DecisionTreeClassifier(max_features='sqrt', random_state=599703810),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1127135564),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1213032774),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1443971201),
#  DecisionTreeClassifier(max_features='sqrt', random_state=501616753)]

# %%
previsoes = floresta.predict(X_teste)
confusao = confusion_matrix(y_teste, previsoes)
taxa_acerto = accuracy_score(y_teste, previsoes)
taxa_acerto
# Out:
# 0.7733333333333333
