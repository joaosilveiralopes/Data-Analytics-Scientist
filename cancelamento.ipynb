# %%
import pandas as pd 
import numpy as np

tabela = pd.read_csv("hotel_bookings.csv")
display(tabela)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
# identificando e removendo valores vazios 

display(tabela.info())
tabela = tabela.dropna()
display(tabela.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# # vamos análisar quantos clientes cancelaram

# %%
display(tabela["is_canceled"].value_counts())
display(tabela["is_canceled"].value_counts(normalize=True).map("{:.1%}".format))

# 92.2% de não cancelados e 7.8% de cancelados
# Out:
# is_canceled
# 0    200
# 1     17
# Name: count, dtype: int64
# is_canceled
# 0    92.2%
# 1     7.8%
# Name: proportion, dtype: object

# %%
display(tabela["arrival_date_month"].value_counts(normalize=True))
display(tabela["arrival_date_month"].value_counts(normalize=True).map("{:.1%}".format))
# descobri que a maior parte do mes da data de chegada foi em novembro
# Out:
# arrival_date_month
# November     0.594470
# October      0.082949
# May          0.082949
# August       0.064516
# January      0.050691
# December     0.023041
# March        0.023041
# July         0.023041
# September    0.023041
# June         0.018433
# February     0.009217
# April        0.004608
# Name: proportion, dtype: float64
# arrival_date_month
# November     59.4%
# October       8.3%
# May           8.3%
# August        6.5%
# January       5.1%
# December      2.3%
# March         2.3%
# July          2.3%
# September     2.3%
# June          1.8%
# February      0.9%
# April         0.5%
# Name: proportion, dtype: object

# %%
display(tabela.groupby("arrival_date_month").mean(numeric_only=True))
# Out:
#                     is_canceled   lead_time  arrival_date_year  \
# arrival_date_month
# April                  1.000000    4.000000        2016.000000
# August                 0.071429    2.285714        2015.357143
# December               0.000000   55.200000        2015.800000
# February               0.000000   11.500000        2016.500000
# January                0.090909    7.272727        2016.636364
# July                   0.000000   96.800000        2016.400000
# June                   0.250000  193.500000        2017.000000
# March                  0.000000   24.200000        2016.800000
# May                    0.055556   10.333333        2016.500000
# November               0.093023   29.465116        2015.031008
# October                0.000000  155.833333        2015.611111
# September              0.000000   41.400000        2015.800000
#
#                     arrival_date_week_number  arrival_date_day_of_month  \
# arrival_date_month
# ...

# %%
# tirei a coluna abril por que dentre os meses que sepassaram foi o mês que mais ouve numeros de cancelamentos
tabela = tabela[tabela["arrival_date_month"]!="april"]
display(tabela)
display(tabela["is_canceled"].value_counts())
display(tabela["is_canceled"].value_counts(normalize=True).map("{:.1%}".format))
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2392    Resort Hotel            0          6               2015
# 2697    Resort Hotel            0         24               2015
# 2867    Resort Hotel            0         24               2015
# 2877    Resort Hotel            0         24               2015
# 2878    Resort Hotel            0         24               2015
# ...              ...          ...        ...                ...
# 112499    City Hotel            0         13               2017
# 113046    City Hotel            0         13               2017
# 113082    City Hotel            0         13               2017
# 113627    City Hotel            0        210               2017
# 116451    City Hotel            0        191               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2392              October                        42
# 2697              October                        44
# ...

# %%
# Resort hotel teve mais hospedagens em comparação com o hotel cidade
display(tabela["hotel"].value_counts(normalize=True).map("{:.1%}".format))
# Out:
# hotel
# Resort Hotel    78.3%
# City Hotel      21.7%
# Name: proportion, dtype: object

# %%
display(tabela.groupby("hotel").mean(numeric_only=True))
# Out:
#               is_canceled  lead_time  arrival_date_year  \
# hotel
# City Hotel       0.042553  70.914894        2016.042553
# Resort Hotel     0.088235  32.117647        2015.305882
#
#               arrival_date_week_number  arrival_date_day_of_month  \
# hotel
# City Hotel                   30.765957                  16.170213
# Resort Hotel                 40.252941                   9.347059
#
#               stays_in_weekend_nights  stays_in_week_nights    adults  \
# hotel
# City Hotel                   0.872340              2.021277  1.702128
# Resort Hotel                 1.758824              5.352941  1.329412
#
#               children  babies  is_repeated_guest  previous_cancellations  \
# hotel
# City Hotel    0.063830     0.0           0.106383                0.000000
# Resort Hotel  0.029412     0.0           0.058824                0.011765
#
#               previous_bookings_not_canceled  booking_changes       agent  \
# hotel
# ...

# %%
display(tabela[tabela["previous_cancellations"]])
# Percebemos que houve mais cancelamentos no hotel resort porem houveram mais pessoas se hospedando nele
# Os  cancelamentos anteriores é muito maior no resort hotel
# A alteração de reserva tam bem é muito maior no resort hotel
# Aprevia de reserva não cancelada é menor no resot hotel
