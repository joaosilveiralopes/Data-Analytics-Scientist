# %%
import pandas as pd
import numpy as np
tabela = pd.read_csv("Netflix Userbase.csv")
display(tabela)
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %%
# Removendo e identificando valores vazios

display(tabela.info())
tabela = tabela.dropna()
display(tabela.info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   object
#  4   Last Payment Date  2500 non-null   object
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 195.4+ KB
# None
# <bound method DataFrame.info of       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# ...

# %%
display(tabela["Subscription Type"].value_counts())
display(tabela["Subscription Type"].value_counts(normalize=True).map("{:.1%}".format))

# Pela analise feita nesse topico vemos que o plano básico é o mais utilizado com 40%
# Out:
# Subscription Type
# Basic       999
# Standard    768
# Premium     733
# Name: count, dtype: int64
# Subscription Type
# Basic       40.0%
# Standard    30.7%
# Premium     29.3%
# Name: proportion, dtype: object

# %%
# Vamos analisar em que aparelho que as pessoas se conectão mais
display(tabela["Device"].value_counts(normalize=True).map("{:.1%}".format))
display(tabela["Device"].value_counts())

# Aparelho que que as pessoas se conectão mais é o laptop 25.5%
# Out:
# Device
# Laptop        25.4%
# Tablet        25.3%
# Smartphone    24.8%
# Smart TV      24.4%
# Name: proportion, dtype: object
# Device
# Laptop        636
# Tablet        633
# Smartphone    621
# Smart TV      610
# Name: count, dtype: int64

# %%
# Agora vamos analisar a nossa faixa etária 
display(tabela["Age"].value_counts(normalize=True).map("{:.1%}".format))
# Out:
# Age
# 39    4.6%
# 30    4.6%
# 28    4.6%
# 31    4.6%
# 41    4.6%
# 47    4.4%
# 37    4.3%
# 35    4.2%
# 29    4.2%
# 40    4.1%
# 42    4.1%
# 48    4.0%
# 46    4.0%
# 36    4.0%
# 49    3.9%
# 43    3.8%
# 33    3.7%
# 51    3.7%
# 32    3.7%
# 45    3.6%
# 38    3.6%
# 34    3.5%
# 27    3.5%
# 44    3.4%
# 50    3.4%
# 26    0.0%
# Name: proportion, dtype: object

# %%
display(tabela["Country"].value_counts(normalize=True).map("{:.1%}".format))
# Out:
# Country
# United States     18.0%
# Spain             18.0%
# Canada            12.7%
# United Kingdom     7.3%
# Australia          7.3%
# Germany            7.3%
# France             7.3%
# Brazil             7.3%
# Mexico             7.3%
# Italy              7.3%
# Name: proportion, dtype: object

# %%
display(tabela["Join Date"].value_counts(normalize=True).map("{:.1%}".format))
# Out:
# Join Date
# 05-11-22    1.3%
# 30-06-22    1.2%
# 16-07-22    1.2%
# 17-07-22    1.2%
# 04-11-22    1.2%
#             ...
# 21-04-22    0.0%
# 30-10-21    0.0%
# 23-11-21    0.0%
# 24-03-23    0.0%
# 15-01-22    0.0%
# Name: proportion, Length: 300, dtype: object

# %%
display(tabela.groupby("Join Date").mean(numeric_only=True))
# Out:
#                User ID  Monthly Revenue        Age
# Join Date
# 01-03-22    111.000000        13.500000  34.000000
# 01-05-23      5.000000        10.000000  33.000000
# 01-06-22    319.333333        10.333333  40.666667
# 01-07-22   1162.684211        13.052632  37.315789
# 01-08-22   1210.461538        12.230769  36.230769
# ...                ...              ...        ...
# 30-11-21     13.000000        12.000000  48.000000
# 31-05-22    339.666667        12.666667  39.333333
# 31-07-22   1374.583333        12.500000  43.250000
# 31-08-22   1100.300000        12.900000  36.300000
# 31-10-22   1513.600000        12.850000  40.550000
#
# [300 rows x 3 columns]

# %%
display(tabela["Monthly Revenue"].value_counts(normalize=True).map("{:.1%}".format))
# Out:
# Monthly Revenue
# 12    18.2%
# 14    17.2%
# 13    16.7%
# 10    16.4%
# 15    16.0%
# 11    15.5%
# Name: proportion, dtype: object

# %%
#import plotly.express as px

#for coluna in tabela.columns:
    #grafico = px.histogram(tabela, x=coluna,color="Device", width=600)
    #grafico.show()
